# %% [markdown]
# # Macroeconomics project
#
# # Task 1

# %% [markdown]
# ### Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the data and creating the DataFrame

# %%
# Creating a dictionary of required links 
urls = {'GDP': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=GDP&scale=left&cosd=1947-01-01&coed=2022-04-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1947-01-01",
        'PCEC': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=PCEC&scale=left&cosd=1947-01-01&coed=2022-04-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1947-01-01",
        'GDP_Implicit_Price_Deflator_inflation': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=A191RI1Q225SBEA&scale=left&cosd=1947-04-01&coed=2022-04-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1947-04-01",
        'CPI_less_food_and_energy': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=CORESTICKM159SFRBATL&scale=left&cosd=1967-12-01&coed=2022-09-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1967-12-01",
        'total_CPI': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=STICKCPIM157SFRBATL&scale=left&cosd=1967-01-01&coed=2022-09-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1967-01-01",
        'Investments': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=GPDI&scale=left&cosd=1947-01-01&coed=2022-04-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1947-01-01",
        'Inventories': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=A371RC1Q027SBEA&scale=left&cosd=1947-01-01&coed=2022-04-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=sum&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1947-01-01",
        'Wilshire_5000_Full_Cap_Price_Index': "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=WILL5000PRFC&scale=left&cosd=1971-01-01&coed=2022-07-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-10-14&revision_date=2022-10-14&nd=1970-12-31"}

# Creating and populating the DataFrame with data (dates and values for each required time series)
df = pd.DataFrame()
for key in urls:
    df[f"{key} Date"] = pd.read_csv(urls[key]).iloc[:,0]
    df[key] = pd.read_csv(urls[key]).iloc[:,1]
    
# Creating and populating a dictionary by assigning to key (time series name) its DataFrame (dates and vaules)
components = {key: None for key in list(urls.keys())}
for i in range(len(urls.keys())):
    components[list(urls.keys())[i]] = pd.DataFrame(df.iloc[:,2*i]).join(pd.DataFrame(df.iloc[:,2*i+1]))
    
# Creating the final DataFrame
data_components = pd.DataFrame({'GDP Date':components['GDP'].iloc[:,0],'GDP':components['GDP'].iloc[:,1]}).rename(columns={'GDP Date':'Date'})
for i in range(len(list(components.keys()))-1):
    name = list(components.keys())[i+1]
    data_components = data_components.merge(components[list(components.keys())[i+1]],
                                           how='left', left_on='Date', right_on=f"{name} Date").drop(columns=f"{name} Date")

data_components = data_components.set_index('Date', drop=True)

# %%
data_components
# Out:
#                   GDP       PCEC  GDP_Implicit_Price_Deflator_inflation  \
# Date
# 1947-01-01    243.164    156.161                                    NaN
# 1947-04-01    245.968    160.031                                    5.8
# 1947-07-01    249.585    163.543                                    6.9
# 1947-10-01    259.745    167.672                                   10.2
# 1948-01-01    265.742    170.372                                    3.2
# ...               ...        ...                                    ...
# 2021-04-01  23046.934  15813.545                                    6.4
# 2021-07-01  23550.420  16147.297                                    6.2
# 2021-10-01  24349.121  16517.976                                    6.8
# 2022-01-01  24740.480  16874.769                                    8.4
# 2022-04-01  25248.476  17261.338                                    9.1
#
#             CPI_less_food_and_energy  total_CPI  Investments  Inventories  \
# Date
# ...

# %% [markdown]
# ### (Optionally) Writing the DataFrame to macro.csv

# %%
data_components.to_csv('macro.csv')

# %% [markdown]
# -----
